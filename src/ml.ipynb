# %%
import pandas as pd

# %%
data = pd.read_csv("../data/tidy_data.csv")

# %%
data
# Out:
#        age         workclass  fnlwgt    education  educationNum     married  \
# 0       39         State-gov   77516    Bachelors            13  notMarried
# 1       50  Self-emp-not-inc   83311    Bachelors            13     married
# 2       38           Private  215646       HSgrad             9  notMarried
# 3       53           Private  234721    nonHSgrad             7     married
# 4       28           Private  338409    Bachelors            13     married
# 5       37           Private  284582      Masters            14     married
# 6       49           Private  160187    nonHSgrad             5     married
# 7       52  Self-emp-not-inc  209642       HSgrad             9     married
# 8       31           Private   45781      Masters            14  notMarried
# 9       42           Private  159449    Bachelors            13     married
# 10      37           Private  280464  someCollege            10     married
# ...
